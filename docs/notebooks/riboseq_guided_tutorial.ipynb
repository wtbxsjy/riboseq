# %% [markdown]
# # Ribo-seq Guided Tutorial / Ribo-seq 交互式教学笔记本
#
# This notebook launches an interactive teaching UI for public-data discovery, download preparation, samplesheet generation, run-command generation, and demo output exploration.
#
# 这个 notebook 会启动一个交互式教学界面，把公开数据查询、下载准备、samplesheet 生成、流程命令生成和 demo 结果浏览串在一起。

# %%
import sys
from pathlib import Path

notebook_dir = Path.cwd().resolve()
if str(notebook_dir) not in sys.path:
    sys.path.insert(0, str(notebook_dir))

from riboseq_guided_tutorial_helpers import launch_tutorial

launch_tutorial()
# Out:
# <div style='padding:8px 10px;border-left:4px solid #1d6d2e;background:#f7f9fc;margin:8px 0'>Repo root detected at: <code>/mnt/c/Users/renzhe/OneDrive - BGI Hong Kong Tech Co., Limited/Polyu/2025s1/RiboSeq/nextflow/riboseq</code></div>
# <div style='padding:8px 10px;border-left:4px solid #1f5aa6;background:#f7f9fc;margin:8px 0'>Run the widgets from top to bottom. This notebook is a guided launcher, not a full GUI.</div>
# VBox(children=(HTML(value='<h2>Ribo-seq Guided Tutorial</h2><p>Step 0 查询公开数据, Step 1 生成下载命令, Step 2 生成 samples…
